# %% [markdown]
# <a href="https://colab.research.google.com/github/sanketjagdale325-png/nlp-pipeline-Practical/blob/main/GENAIPractical3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
sample_text = """The quick brown fox jumps over the lazy dog.

The quick brown fox is a fox.

The lazy dog sleeps all day.

Dogs are loyal animals.
"""

with open('input.txt', 'w') as f:
    f.write(sample_text)

print("Created 'input.txt' with sample content.")
# Out:
# Created 'input.txt' with sample content.

# %% [markdown]
# Now that `input.txt` has been created, you can run the cells that load and tokenize the data.

# %%
# 1. Load and Tokenize Data
with open('input.txt', 'r') as f:
    text = f.read().lower().split('\n')

tokenizer = Tokenizer()
tokenizer.fit_on_texts(text)
total_words = len(tokenizer.word_index) + 1

# %%
#2. Prepare N-gram Sequences
input_sequences = []
for line in text:
  token_list = tokenizer.texts_to_sequences([line])[0]
  for i in range(1, len(token_list)):
    input_sequences.append(token_list[:i+1])

max_seq_len = max(len(seq) for seq in input_sequences)
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_seq_len,padding='pre'))
X,y = input_sequences[:,:-1],input_sequences[:,-1]

# %%
#3. Build and Train RNN Model
model = Sequential([
    Embedding(total_words, 10),
    SimpleRNN(50),
    Dense(total_words, activation='softmax')
])
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam')
model.fit(X,y, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 2.8951
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 2.8812
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 2.8679
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.8549
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 2.8418
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 2.8286
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 2.8149
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.8006
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 2.7857
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 2.7699
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 2.7531
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 2.7352
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 2.7162
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 2.6960
# Epoch 15/100
# ...

# %%
#4. Predict Next Word from User Input
while True:
    user_text = input("Enter a seed text (type 'exit' to quit): ")
    if user_text == 'exit':
        break
    seq = pad_sequences(tokenizer.texts_to_sequences([user_text]), maxlen=max_seq_len-1, padding='pre')
    pred_idx = np.argmax(model.predict(seq, verbose = 0), axis = -1)[0]
    print(f"Predicted next word: {tokenizer.index_word.get(pred_idx, '')}\n")
# Out:
# Enter a seed text (type 'exit' to quit): the quick brown fox
# Predicted next word: is
#
# Enter a seed text (type 'exit' to quit): exit
